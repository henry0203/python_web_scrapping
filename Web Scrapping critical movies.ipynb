# %%
#https://www.imdb.com/search/title/?release_date=2017-01-01,2017-12-31&sort=num_votes,desc
from requests import get
from bs4 import BeautifulSoup
url = "https://www.imdb.com/search/title/?release_date=2017-01-01,2017-12-31&sort=num_votes,desc"
response = get(url)
#print(response.text[:500])
html_soup = BeautifulSoup(response.text, "html.parser")
#print(type(html_soup))
#print("        ")
movie_containers = html_soup.find_all("div", class_="lister-item mode-advanced")
print(type(movie_containers))
print(len(movie_containers))
print(movie.prettify())
# Out:
# <class 'bs4.element.ResultSet'>
# 50
# <div class="lister-item mode-advanced">
#  <div class="lister-top-right">
#   <div class="ribbonize" data-caller="filmosearch" data-tconst="tt3920596">
#   </div>
#  </div>
#  <div class="lister-item-image float-left">
#   <a href="/title/tt3920596/">
#    <img alt="Big Little Lies" class="loadlate" data-tconst="tt3920596" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BZmNjYzdjN2ItOTBlNy00Mjc0LWE4YmMtYTQ4ZjQzNTMyNDc4XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB466725069_.png" width="67"/>
#   </a>
#  </div>
#  <div class="lister-item-content">
#   <h3 class="lister-item-header">
#    <span class="lister-item-index unbold text-primary">
#     50.
#    </span>
#    <a href="/title/tt3920596/">
#     Big Little Lies
#    </a>
#    <span class="lister-item-year text-muted unbold">
#     (2017–2019)
#    </span>
#   </h3>
# ...

# %%
#Extract data from movies
first_movie = movie_containers[0]
first_name = first_movie.h3.a.text
print(first_name)
first_date = first_movie.h3.find("span", class_="lister-item-year text-muted unbold").text
print(first_date)
first_imdb = first_movie.find(class_="inline-block ratings-imdb-rating").strong.text
print(float(first_imdb))
first_metascore = first_movie.find(class_="metascore favorable").text
print(int(first_metascore))
first_votes = first_movie.find("span", attrs={"name":"nv"})["data-value"]
print(int(first_votes))
# Out:
# Logan
# (2017)
# 8.1
# 77
# 617378

# %% [markdown]
# ## Script to scrap unique page

# %%
test_movie_metascore = int(movie_containers[8].find(class_="metascore favorable").text)
test_movie_metascore
# Out:
# 69

# %%
import pandas as pd

names=[]
years=[]
imdb_ratings=[]
metascores=[]
votes=[]

for movie in movie_containers:
    if movie.find(class_="metascore favorable") is not None:
        #print(type(movie.find(class_="metascore favorable").text))
        names.append(movie.h3.a.text)
        years.append(movie.h3.find("span", class_="lister-item-year text-muted unbold").text)
        imdb_ratings.append(movie.find(class_="inline-block ratings-imdb-rating").strong.text)
        metascores.append(int(movie.find(class_="metascore favorable").text))
        votes.append(movie.find("span", attrs={"name":"nv"})["data-value"])

#print(names, years, imdb_ratings, metascores, votes)
print(len(metascores))

df = pd.DataFrame({
    "name": names,
    "year": years,
    "imdb rating": imdb_ratings, 
    "metascore": metascores,
    "vote": votes
})
df
# Out:
# 27
#                                            name        year imdb rating  \
# 0                                         Logan      (2017)         8.1
# 1                                Thor: Ragnarok      (2017)         7.9
# 2             Les gardiens de la galaxie Vol. 2      (2017)         7.6
# 3   Star Wars: Episode VIII - Les derniers Jedi      (2017)         7.0
# 4                                  Wonder Woman      (2017)         7.4
# 5                                     Dunkerque      (2017)         7.9
# 6                        Spider-Man: Homecoming      (2017)         7.4
# 7                                       Get Out  (I) (2017)         7.7
# 8                                            Ça  (I) (2017)         7.3
# 9                             Blade Runner 2049      (2017)         8.0
# 10                                  Baby Driver      (2017)         7.6
# 11   3 Billboards: Les panneaux de la vengeance      (2017)         8.2
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         27 non-null     object
#  1   year         27 non-null     object
#  2   imdb rating  27 non-null     object
#  3   metascore    27 non-null     int64
#  4   vote         27 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.2+ KB
# None

# %% [markdown]
# ## Scrap all the pages

# %%
from time import sleep 
from random import randint

#Set variables values
pages = [str(i) for i in range(1,5)]
print(pages)
years_url = [str(i) for i in range(2000,2018)]
print(years_url)
#Control requests number

for i in range(0,5):
    print("Booh")
    sleep(randint(1,4))
# Out:
# ['1', '2', '3', '4']
# ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']
# Booh
# Booh
# Booh
# Booh
# Booh

# %%
from time import time 
from IPython.display import clear_output
from warnings import warn
start_time = time()
requests = 0 #count number of requests
for _ in range(5):
    requests+=1
    sleep(randint(1,3))
    elapsed_time = time() - start_time
    print("Request : {}; Frequency : {} requests/s".format(requests, requests/elapsed_time))
    clear_output(wait=True)
warn('Attention')
# Out:
# /Users/henrymacbook/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: Attention
#   if sys.path[0] == '':

# %%
from requests import get
from bs4 import BeautifulSoup
from time import sleep
from random import randint
from time import time
from IPython.display import clear_output
 
import pandas as pd
 
# Modification liée au changement de structure de l'url de recherche
# L'url n'est plus classée par page mais par premier élément
# Chaque page de recherche contient toujours 50 films
# Donc voici le nouvel url de recherche avec first_film qui prendra les valeurs 1, 51, 101,...:
# 'http://www.imdb.com/search/title?release_date='+ year_url +'&sort=num_votes,desc&start='+ start
 
starts = [str(i) for i in range(1,201,50)]
 
years_url = [str(i) for i in range(2000,2018)]
 
# 1. Redéclarer les listes
names = []
years = []
imdb_ratings =[]
metascores = []
votes = []
 
# 2. préparer l'affichage des boucles
start_time = time()
requests = 0
 
# 3. Pour chaque année de l'intervalle 2000-2017
for year_url in years_url:
    
    # 4. boucle sur starts contenant les premiers films des pages de 1 à 4
    for start in starts:
        
        # 5. Faire une requête GET
        response = get('http://www.imdb.com/search/title?release_date='+ year_url +'&sort=num_votes,desc&start='+ start)
        
        # 6. Pause la boucle de 8 à 15 secondes
        sleep(randint(8,15))
        
        # 7. Afficher les informations sur les requêtes
        requests += 1
        elapsed_time = time() - start_time
        print('Request: {}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
        clear_output(wait = True)
        
        # 8. Avertir si le code status est différent de 200
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(requests, response.status_code))
            
        # 9. Stopper la boucle si le nombre de requêtes est supérieur à 72
        if requests > 72:
            warn('Nombre de requêtes trop important')
            break
            
        # 10. Extraire le HTML avec BeautifulSoup
        page_html = BeautifulSoup(response.text, 'html.parser')
        
        # 11. Sélectionner les 50 films de chaque page (container)
        mv_containers = page_html.find_all('div', class_="lister-item mode-advanced")
        
        # 12. Boucle pour chaque container
        for container in mv_containers:
            # 13. Si le film a un Metascore
            if container.find('div', class_='ratings-metascore') is not None:
                
                # 14. scrape le titre
                name = container.h3.a.text
                names.append(name)
                
                #15. scrape l'année
                year = container.h3.find('span', class_='lister-item-year').text
                years.append(year)
                
                #16. scrape la note IMDB
                imdb = float(container.strong.text)
                imdb_ratings.append(imdb)
                
                #17. scrape le Metascore
                metascore = container.find('span', class_='metascore').text
                metascores.append(int(metascore))
                
                #18. scrape le nombre de votes
                vote = container.find('span', attrs = {'name':'nv'})['data-value']
                votes.append(int(vote))
 
# Afficher les 100 premiers films dans un DataFrame
movie_ratings = pd.DataFrame({
        'movie': names,
        'year': years,
        'imdb': imdb_ratings,
        'metascore': metascores,
        'votes': votes
    })
 
movie_ratings.head(100)
print(movie_ratings.info())
# Out:
#                                movie    year  imdb  metascore    votes
# 0                          Gladiator  (2000)   8.5         67  1292687
# 1                            Memento  (2000)   8.4         80  1086399
# 2   Snatch - Tu braques ou tu raques  (2000)   8.3         55   759219
# 3                Requiem for a Dream  (2000)   8.3         68   740706
# 4                              X-Men  (2000)   7.4         64   557983
# ..                               ...     ...   ...        ...      ...
# 95                       Nurse Betty  (2000)   6.1         69    32471
# 96                        Get Carter  (2000)   5.2         24    31899
# 97                 Donjons & dragons  (2000)   3.6         14    31459
# 98                      Dracula 2001  (2000)   4.9         26    31392
# 99             Où le coeur nous mène  (2000)   6.8         30    31144
#
# [100 rows x 5 columns]
